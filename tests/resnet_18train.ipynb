# %%
import time
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import StepLR
from deepmoe_utils import deepmoe_loss
from deepResNet import resnet18_moe
from ResNet import resnet18

# %%
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761))
])

train_dataset = datasets.CIFAR100(root='./data', train=True, download=True, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=4)

val_dataset = datasets.CIFAR100(root='./data', train=False, download=True, transform=transform)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False, num_workers=4)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def train(model, device, train_loader, optimizer, criterion, moe=False):
    model.train()
    total_loss, correct = 0, 0
    for data, target in train_loader:
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        if not moe:
            output = model(data)
            loss = criterion(output, target)
        else:
            output, gates, emb_y_hat = model(data)
            loss = criterion(output, emb_y_hat, target, gates)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        pred = output.argmax(dim=1, keepdim=True)
        correct += pred.eq(target.view_as(pred)).sum().item()
    
    return total_loss / len(train_loader), correct / len(train_loader.dataset)

# %%
def validate(model, device, val_loader, criterion, moe=False):
    model.eval()
    total_loss, correct = 0, 0
    with torch.no_grad():
        for data, target in val_loader:
            data, target = data.to(device), target.to(device)
            if not moe:
                output = model(data)
                loss = criterion(output, target)
            else:
                output, gates, emb_y_hat = model(data)
                loss = criterion(output, emb_y_hat, target, gates)
            
            total_loss += loss.item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
            
    return total_loss / len(val_loader), correct / len(val_loader.dataset)

# %%
def main():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    # Initialize models
    model_resnet18 = resnet18(num_classes=100).to(device)
    model_resnet18_moe = resnet18_moe(num_classes=100).to(device)
    
    # Initialize optimizers
    optimizer_resnet18 = optim.Adam(model_resnet18.parameters(), lr=0.001)
    optimizer_resnet18_moe = optim.Adam(model_resnet18_moe.parameters(), lr=0.001)
    
    # Initialize criteria and schedulers
    res_criterion = nn.CrossEntropyLoss()
    moe_criterion = deepmoe_loss(lambda_val=1.0, mu=1.0)
    scheduler_resnet18 = StepLR(optimizer_resnet18, step_size=20, gamma=0.5)
    scheduler_resnet18_moe = StepLR(optimizer_resnet18_moe, step_size=20, gamma=0.5)
    
    num_epochs = 25
    for epoch in range(num_epochs):
        print(f"Epoch {epoch+1}/{num_epochs}")
        
        # Update moe_criterion parameters for the last 5 epochs
        if epoch >= num_epochs - 5:
            moe_criterion = deepmoe_loss(lambda_val=0.0, mu=0.0)
        
        # Train and validate ResNet-18
        start_time_train_resnet18 = time.time()
        train_loss_resnet18, train_acc_resnet18 = train(model_resnet18, device, train_loader, optimizer_resnet18, res_criterion)
        end_time_train_resnet18 = time.time()
        train_duration_resnet18 = end_time_train_resnet18 - start_time_train_resnet18
        
        start_time_val_resnet18 = time.time()
        val_loss_resnet18, val_acc_resnet18 = validate(model_resnet18, device, val_loader, res_criterion)
        end_time_val_resnet18 = time.time()
        val_duration_resnet18 = end_time_val_resnet18 - start_time_val_resnet18
        
        # Train and validate ResNet-18 MoE
        start_time_train_resnet18_moe = time.time()
        train_loss_resnet18_moe, train_acc_resnet18_moe = train(model_resnet18_moe, device, train_loader, optimizer_resnet18_moe, moe_criterion, True)
        end_time_train_resnet18_moe = time.time()
        train_duration_resnet18_moe = end_time_train_resnet18_moe - start_time_train_resnet18_moe
        
        start_time_val_resnet18_moe = time.time()
        val_loss_resnet18_moe, val_acc_resnet18_moe = validate(model_resnet18_moe, device, val_loader, moe_criterion, True)
        end_time_val_resnet18_moe = time.time()
        val_duration_resnet18_moe = end_time_val_resnet18_moe - start_time_val_resnet18_moe
        
        print(f"ResNet18 - Loss: {train_loss_resnet18:.4f}, Acc: {train_acc_resnet18:.4f} | Val Loss: {val_loss_resnet18:.4f}, Val Acc: {val_acc_resnet18:.4f}")
        print(f"ResNet18 MoE - Loss: {train_loss_resnet18_moe:.4f}, Acc: {train_acc_resnet18_moe:.4f} | Val Loss: {val_loss_resnet18_moe:.4f}, Val Acc: {val_acc_resnet18_moe:.4f}")
        
        print(f"ResNet18 Training Duration: {train_duration_resnet18:.2f} seconds")
        print(f"ResNet18 Validation Duration: {val_duration_resnet18:.2f} seconds")
        print(f"ResNet18 MoE Training Duration: {train_duration_resnet18_moe:.2f} seconds")
        print(f"ResNet18 MoE Validation Duration: {val_duration_resnet18_moe:.2f} seconds")
        
        # Update schedulers
        scheduler_resnet18.step()
        scheduler_resnet18_moe.step()

if __name__ == "__main__":
    main()
# Out:
# Epoch 1/25
# ResNet18 - Loss: 3.8458, Acc: 0.1081 | Val Loss: 3.6047, Val Acc: 0.1446
# ResNet18 MoE - Loss: 12.2819, Acc: 0.0854 | Val Loss: 9.7104, Val Acc: 0.0959
# ResNet18 Training Duration: 63.87 seconds
# ResNet18 Validation Duration: 5.05 seconds
# ResNet18 MoE Training Duration: 84.43 seconds
# ResNet18 MoE Validation Duration: 6.50 seconds
# Epoch 2/25
# ResNet18 - Loss: 3.1764, Acc: 0.2150 | Val Loss: 3.0281, Val Acc: 0.2455
# ResNet18 MoE - Loss: 8.7602, Acc: 0.1203 | Val Loss: 8.3087, Val Acc: 0.1346
# ResNet18 Training Duration: 66.71 seconds
# ResNet18 Validation Duration: 5.33 seconds
# ResNet18 MoE Training Duration: 84.55 seconds
# ResNet18 MoE Validation Duration: 6.41 seconds
# Epoch 3/25
# ResNet18 - Loss: 2.6174, Acc: 0.3234 | Val Loss: 2.5170, Val Acc: 0.3478
# ResNet18 MoE - Loss: 8.1490, Acc: 0.1436 | Val Loss: 7.9337, Val Acc: 0.1458
# ResNet18 Training Duration: 65.56 seconds
# ResNet18 Validation Duration: 5.04 seconds
# ResNet18 MoE Training Duration: 84.18 seconds
# ResNet18 MoE Validation Duration: 6.33 seconds
# Epoch 4/25
# ResNet18 - Loss: 2.1830, Acc: 0.4149 | Val Loss: 2.2031, Val Acc: 0.4130
# ResNet18 MoE - Loss: 7.7524, Acc: 0.1688 | Val Loss: 7.6882, Val Acc: 0.1751
# ResNet18 Training Duration: 65.30 seconds
# ResNet18 Validation Duration: 4.98 seconds
# ResNet18 MoE Training Duration: 84.39 seconds
# ResNet18 MoE Validation Duration: 6.37 seconds
# Epoch 5/25
# ResNet18 - Loss: 1.8919, Acc: 0.4792 | Val Loss: 2.0858, Val Acc: 0.4462
# ResNet18 MoE - Loss: 7.5208, Acc: 0.1927 | Val Loss: 7.4998, Val Acc: 0.1959
# ResNet18 Training Duration: 65.33 seconds
# ResNet18 Validation Duration: 5.08 seconds
# ResNet18 MoE Training Duration: 84.23 seconds
# ResNet18 MoE Validation Duration: 6.37 seconds
# Epoch 20/25
# ResNet18 - Loss: 0.3492, Acc: 0.8871 | Val Loss: 1.3229, Val Acc: 0.6741
# ResNet18 MoE - Loss: 5.6046, Acc: 0.2887 | Val Loss: 5.7116, Val Acc: 0.2719
# ResNet18 Training Duration: 65.22 seconds
# ResNet18 Validation Duration: 5.17 seconds
# ResNet18 MoE Training Duration: 84.06 seconds
# ResNet18 MoE Validation Duration: 6.38 seconds
# Epoch 21/25
# ResNet18 - Loss: 0.1929, Acc: 0.9442 | Val Loss: 1.1718, Val Acc: 0.7081
# ResNet18 MoE - Loss: 2.7773, Acc: 0.3070 | Val Loss: 2.8699, Val Acc: 0.2930
# ResNet18 Training Duration: 65.42 seconds
# ResNet18 Validation Duration: 5.08 seconds
# ResNet18 MoE Training Duration: 83.84 seconds
# ResNet18 MoE Validation Duration: 6.34 seconds
# Epoch 22/25
# ResNet18 - Loss: 0.1443, Acc: 0.9607 | Val Loss: 1.1952, Val Acc: 0.7139
# ResNet18 MoE - Loss: 2.7139, Acc: 0.3197 | Val Loss: 2.8010, Val Acc: 0.3082
# ResNet18 Training Duration: 65.13 seconds
# ResNet18 Validation Duration: 5.03 seconds
# ResNet18 MoE Training Duration: 84.13 seconds
# ResNet18 MoE Validation Duration: 6.40 seconds
# Epoch 23/25
# ResNet18 - Loss: 0.1170, Acc: 0.9697 | Val Loss: 1.2418, Val Acc: 0.7068
# ResNet18 MoE - Loss: 2.6669, Acc: 0.3280 | Val Loss: 2.8094, Val Acc: 0.3103
# ResNet18 Training Duration: 65.16 seconds
# ResNet18 Validation Duration: 5.04 seconds
# ResNet18 MoE Training Duration: 83.99 seconds
# ResNet18 MoE Validation Duration: 6.49 seconds
# Epoch 24/25
# ResNet18 - Loss: 0.1103, Acc: 0.9702 | Val Loss: 1.3078, Val Acc: 0.7017
# ResNet18 MoE - Loss: 2.6086, Acc: 0.3401 | Val Loss: 2.7167, Val Acc: 0.3188
# ResNet18 Training Duration: 65.40 seconds
# ResNet18 Validation Duration: 5.10 seconds
# ResNet18 MoE Training Duration: 84.05 seconds
# ResNet18 MoE Validation Duration: 6.29 seconds
# Epoch 25/25
# ResNet18 - Loss: 0.1084, Acc: 0.9699 | Val Loss: 1.3389, Val Acc: 0.6962
# ResNet18 MoE - Loss: 2.5583, Acc: 0.3519 | Val Loss: 2.6972, Val Acc: 0.3277
# ResNet18 Training Duration: 65.46 seconds
# ResNet18 Validation Duration: 5.38 seconds
# ResNet18 MoE Training Duration: 84.83 seconds
# ResNet18 MoE Validation Duration: 6.34 seconds

# %%
def main2():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    # Initialize models
    model_resnet18_moe = resnet18_moe(num_classes=100).to(device)
    
    # Initialize optimizers
    optimizer_resnet18_moe = optim.Adam(model_resnet18_moe.parameters(), lr=0.001)
    
    # Initialize criteria and schedulers
    moe_criterion = deepmoe_loss(lambda_val=0.001, mu=1.0)
    scheduler_resnet18_moe = StepLR(optimizer_resnet18_moe, step_size=20, gamma=0.5)
    
    num_epochs = 25
    for epoch in range(num_epochs):
        print(f"Epoch {epoch+1}/{num_epochs}")
        
        # Update moe_criterion parameters for the last 5 epochs
        if epoch >= num_epochs - 5:
            moe_criterion = deepmoe_loss(lambda_val=0.0, mu=0.0)
        
        # Train ResNet-18 MoE
        start_time_train_resnet18_moe = time.time()
        train_loss_resnet18_moe, train_acc_resnet18_moe = train(model_resnet18_moe, device, train_loader, optimizer_resnet18_moe, moe_criterion, True)
        end_time_train_resnet18_moe = time.time()
        train_duration_resnet18_moe = end_time_train_resnet18_moe - start_time_train_resnet18_moe
        
        # Validate ResNet-18 MoE
        start_time_val_resnet18_moe = time.time()
        val_loss_resnet18_moe, val_acc_resnet18_moe = validate(model_resnet18_moe, device, val_loader, moe_criterion, True)
        end_time_val_resnet18_moe = time.time()
        val_duration_resnet18_moe = end_time_val_resnet18_moe - start_time_val_resnet18_moe
        
        print(f"ResNet18 MoE - Loss: {train_loss_resnet18_moe:.4f}, Acc: {train_acc_resnet18_moe:.4f} | Val Loss: {val_loss_resnet18_moe:.4f}, Val Acc: {val_acc_resnet18_moe:.4f}")
        print(f"ResNet18 MoE Training Duration: {train_duration_resnet18_moe:.2f} seconds")
        print(f"ResNet18 MoE Validation Duration: {val_duration_resnet18_moe:.2f} seconds")
        
        # Update schedulers
        scheduler_resnet18_moe.step()

if __name__ == "__main__":
    main2()
# Out:
# Epoch 1/25
# ResNet18 MoE - Loss: 8.4175, Acc: 0.0745 | Val Loss: 8.8274, Val Acc: 0.0961
# ResNet18 MoE Training Duration: 85.05 seconds
# ResNet18 MoE Validation Duration: 6.35 seconds
# Epoch 2/25
# ResNet18 MoE - Loss: 7.7057, Acc: 0.1196 | Val Loss: 19.0168, Val Acc: 0.1375
# ResNet18 MoE Training Duration: 84.70 seconds
# ResNet18 MoE Validation Duration: 6.48 seconds
# Epoch 3/25
# ResNet18 MoE - Loss: 7.1358, Acc: 0.1717 | Val Loss: 7.0516, Val Acc: 0.1861
# ResNet18 MoE Training Duration: 84.53 seconds
# ResNet18 MoE Validation Duration: 6.69 seconds
# Epoch 4/25
# ResNet18 MoE - Loss: 6.6460, Acc: 0.2166 | Val Loss: 8.5427, Val Acc: 0.2319
# ResNet18 MoE Training Duration: 84.87 seconds
# ResNet18 MoE Validation Duration: 6.34 seconds
# Epoch 5/25
# ResNet18 MoE - Loss: 6.1332, Acc: 0.2628 | Val Loss: 116.9042, Val Acc: 0.2500
# ResNet18 MoE Training Duration: 83.81 seconds
# ResNet18 MoE Validation Duration: 6.38 seconds
# Epoch 6/25
# ResNet18 MoE - Loss: 5.7152, Acc: 0.3045 | Val Loss: 15.7891, Val Acc: 0.2950
# ResNet18 MoE Training Duration: 84.14 seconds
# ResNet18 MoE Validation Duration: 6.45 seconds
# Epoch 7/25
# ResNet18 MoE - Loss: 5.3834, Acc: 0.3348 | Val Loss: 9.5117, Val Acc: 0.3324
# ResNet18 MoE Training Duration: 84.25 seconds
# ResNet18 MoE Validation Duration: 6.41 seconds
# Epoch 8/25
# ResNet18 MoE - Loss: 5.0414, Acc: 0.3687 | Val Loss: 8.5238, Val Acc: 0.3480
# ResNet18 MoE Training Duration: 84.27 seconds
# ResNet18 MoE Validation Duration: 6.42 seconds
# Epoch 9/25
# ResNet18 MoE - Loss: 4.7944, Acc: 0.3934 | Val Loss: 1051438336182477.6250, Val Acc: 0.3256
# ResNet18 MoE Training Duration: 84.27 seconds
# ResNet18 MoE Validation Duration: 6.43 seconds
# Epoch 10/25
# ResNet18 MoE - Loss: 4.6155, Acc: 0.4166 | Val Loss: 5.6760, Val Acc: 0.3793
# ResNet18 MoE Training Duration: 84.32 seconds
# ResNet18 MoE Validation Duration: 6.44 seconds
# Epoch 11/25
# ResNet18 MoE - Loss: 4.4016, Acc: 0.4400 | Val Loss: 2404.7491, Val Acc: 0.4214
# ResNet18 MoE Training Duration: 84.38 seconds
# ResNet18 MoE Validation Duration: 6.43 seconds
# Epoch 12/25
# ResNet18 MoE - Loss: 4.1588, Acc: 0.4664 | Val Loss: 8.6619, Val Acc: 0.4389
# ResNet18 MoE Training Duration: 84.28 seconds
# ResNet18 MoE Validation Duration: 6.45 seconds
# Epoch 13/25
# ResNet18 MoE - Loss: 3.9550, Acc: 0.4889 | Val Loss: 4.3967, Val Acc: 0.4590
# ResNet18 MoE Training Duration: 84.44 seconds
# ResNet18 MoE Validation Duration: 6.56 seconds
# Epoch 14/25
# ResNet18 MoE - Loss: 3.7909, Acc: 0.5092 | Val Loss: 6.2008, Val Acc: 0.4682
# ResNet18 MoE Training Duration: 84.78 seconds
# ResNet18 MoE Validation Duration: 6.42 seconds
# Epoch 15/25
# ResNet18 MoE - Loss: 3.6885, Acc: 0.5239 | Val Loss: 5.4565, Val Acc: 0.4756
# ResNet18 MoE Training Duration: 84.42 seconds
# ResNet18 MoE Validation Duration: 6.65 seconds
# Epoch 16/25
# ResNet18 MoE - Loss: 3.5805, Acc: 0.5362 | Val Loss: 1251361133.5488, Val Acc: 0.4745
# ResNet18 MoE Training Duration: 84.56 seconds
# ResNet18 MoE Validation Duration: 6.32 seconds
# Epoch 17/25
# ResNet18 MoE - Loss: 3.5124, Acc: 0.5462 | Val Loss: 34.9000, Val Acc: 0.4830
# ResNet18 MoE Training Duration: 84.53 seconds
# ResNet18 MoE Validation Duration: 6.70 seconds
# Epoch 18/25
# ResNet18 MoE - Loss: 3.3651, Acc: 0.5626 | Val Loss: 31.4188, Val Acc: 0.4894
# ResNet18 MoE Training Duration: 84.63 seconds
# ResNet18 MoE Validation Duration: 6.40 seconds
# Epoch 19/25
# ResNet18 MoE - Loss: 3.2060, Acc: 0.5829 | Val Loss: 7.9634, Val Acc: 0.4969
# ResNet18 MoE Training Duration: 84.91 seconds
# ResNet18 MoE Validation Duration: 6.77 seconds
# Epoch 20/25
# ResNet18 MoE - Loss: 3.0927, Acc: 0.5950 | Val Loss: 4.5883, Val Acc: 0.5103
# ResNet18 MoE Training Duration: 84.40 seconds
# ResNet18 MoE Validation Duration: 6.40 seconds
# Epoch 21/25
# ResNet18 MoE - Loss: 1.2555, Acc: 0.6372 | Val Loss: 1.9374, Val Acc: 0.5428
# ResNet18 MoE Training Duration: 84.64 seconds
# ResNet18 MoE Validation Duration: 6.44 seconds
# Epoch 22/25
# ResNet18 MoE - Loss: 1.2567, Acc: 0.6389 | Val Loss: 2.0675, Val Acc: 0.5359
# ResNet18 MoE Training Duration: 84.80 seconds
# ResNet18 MoE Validation Duration: 6.51 seconds
# Epoch 23/25
# ResNet18 MoE - Loss: 1.1880, Acc: 0.6573 | Val Loss: 523870.7395, Val Acc: 0.5385
# ResNet18 MoE Training Duration: 84.19 seconds
# ResNet18 MoE Validation Duration: 6.82 seconds
# Epoch 24/25
# ResNet18 MoE - Loss: 1.1566, Acc: 0.6646 | Val Loss: 12.6045, Val Acc: 0.5476
# ResNet18 MoE Training Duration: 84.50 seconds
# ResNet18 MoE Validation Duration: 6.40 seconds
# Epoch 25/25
# ResNet18 MoE - Loss: 1.1216, Acc: 0.6706 | Val Loss: 276.2478, Val Acc: 0.5472
# ResNet18 MoE Training Duration: 84.98 seconds
# ResNet18 MoE Validation Duration: 6.70 seconds

# %%
def main3():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    # Initialize models
    model_resnet18_moe = resnet18_moe(num_classes=100).to(device)
    
    # Initialize optimizers
    optimizer_resnet18_moe = optim.Adam(model_resnet18_moe.parameters(), lr=0.001)
    
    # Initialize criteria and schedulers
    moe_criterion = deepmoe_loss(lambda_val=0.001, mu=0.1)
    scheduler_resnet18_moe = StepLR(optimizer_resnet18_moe, step_size=20, gamma=0.5)
    
    num_epochs = 25
    for epoch in range(num_epochs):
        print(f"Epoch {epoch+1}/{num_epochs}")
        
        # Update moe_criterion parameters for the last 5 epochs
        if epoch >= num_epochs - 5:
            moe_criterion = deepmoe_loss(lambda_val=0.0, mu=0.0)
        
        # Train ResNet-18 MoE
        start_time_train_resnet18_moe = time.time()
        train_loss_resnet18_moe, train_acc_resnet18_moe = train(model_resnet18_moe, device, train_loader, optimizer_resnet18_moe, moe_criterion, True)
        end_time_train_resnet18_moe = time.time()
        train_duration_resnet18_moe = end_time_train_resnet18_moe - start_time_train_resnet18_moe
        
        # Validate ResNet-18 MoE
        start_time_val_resnet18_moe = time.time()
        val_loss_resnet18_moe, val_acc_resnet18_moe = validate(model_resnet18_moe, device, val_loader, moe_criterion, True)
        end_time_val_resnet18_moe = time.time()
        val_duration_resnet18_moe = end_time_val_resnet18_moe - start_time_val_resnet18_moe
        
        print(f"ResNet18 MoE - Loss: {train_loss_resnet18_moe:.4f}, Acc: {train_acc_resnet18_moe:.4f} | Val Loss: {val_loss_resnet18_moe:.4f}, Val Acc: {val_acc_resnet18_moe:.4f}")
        print(f"ResNet18 MoE Training Duration: {train_duration_resnet18_moe:.2f} seconds")
        print(f"ResNet18 MoE Validation Duration: {val_duration_resnet18_moe:.2f} seconds")
        
        # Update schedulers
        scheduler_resnet18_moe.step()

if __name__ == "__main__":
    main3()
# Out:
# Epoch 1/25
# ResNet18 MoE - Loss: 4.6307, Acc: 0.0672 | Val Loss: 4.8587, Val Acc: 0.0812
# ResNet18 MoE Training Duration: 85.42 seconds
# ResNet18 MoE Validation Duration: 6.79 seconds
# Epoch 2/25
# ResNet18 MoE - Loss: 4.3023, Acc: 0.1044 | Val Loss: 383.2595, Val Acc: 0.1008
# ResNet18 MoE Training Duration: 85.33 seconds
# ResNet18 MoE Validation Duration: 6.51 seconds
# Epoch 3/25
# ResNet18 MoE - Loss: 4.1571, Acc: 0.1291 | Val Loss: 278.5084, Val Acc: 0.1323
# ResNet18 MoE Training Duration: 85.56 seconds
# ResNet18 MoE Validation Duration: 6.37 seconds
# Epoch 4/25
# ResNet18 MoE - Loss: 4.1732, Acc: 0.1473 | Val Loss: 155489358.8796, Val Acc: 0.1557
# ResNet18 MoE Training Duration: 84.99 seconds
# ResNet18 MoE Validation Duration: 6.46 seconds
# Epoch 5/25
# ResNet18 MoE - Loss: 3.9890, Acc: 0.1751 | Val Loss: 27.2217, Val Acc: 0.1950
# ResNet18 MoE Training Duration: 84.58 seconds
# ResNet18 MoE Validation Duration: 6.45 seconds
# Epoch 6/25
# ResNet18 MoE - Loss: 3.8610, Acc: 0.1947 | Val Loss: 159503.7253, Val Acc: 0.1873
# ResNet18 MoE Training Duration: 84.45 seconds
# ResNet18 MoE Validation Duration: 6.46 seconds
# Epoch 7/25
# ResNet18 MoE - Loss: 3.7661, Acc: 0.2077 | Val Loss: 11864852.5935, Val Acc: 0.2135
# ResNet18 MoE Training Duration: 84.21 seconds
# ResNet18 MoE Validation Duration: 6.45 seconds
# Epoch 8/25
# ResNet18 MoE - Loss: 3.7699, Acc: 0.2156 | Val Loss: 3.7495, Val Acc: 0.2213
# ResNet18 MoE Training Duration: 84.46 seconds
# ResNet18 MoE Validation Duration: 6.54 seconds
# Epoch 9/25
# ResNet18 MoE - Loss: 3.6511, Acc: 0.2289 | Val Loss: 3191.5082, Val Acc: 0.2218
# ResNet18 MoE Training Duration: 84.61 seconds
# ResNet18 MoE Validation Duration: 6.53 seconds
# Epoch 10/25
# ResNet18 MoE - Loss: 3.4590, Acc: 0.2554 | Val Loss: 5.0803, Val Acc: 0.2667
# ResNet18 MoE Training Duration: 84.35 seconds
# ResNet18 MoE Validation Duration: 6.46 seconds
# Epoch 11/25
# ResNet18 MoE - Loss: 3.2861, Acc: 0.2795 | Val Loss: 4.2653, Val Acc: 0.2754
# ResNet18 MoE Training Duration: 83.96 seconds
# ResNet18 MoE Validation Duration: 6.46 seconds
# Epoch 12/25
# ResNet18 MoE - Loss: 3.2069, Acc: 0.2956 | Val Loss: 3.3973, Val Acc: 0.2930
# ResNet18 MoE Training Duration: 84.06 seconds
# ResNet18 MoE Validation Duration: 6.36 seconds
# Epoch 13/25
# ResNet18 MoE - Loss: 3.1596, Acc: 0.3075 | Val Loss: 3.4329, Val Acc: 0.2589
# ResNet18 MoE Training Duration: 84.62 seconds
# ResNet18 MoE Validation Duration: 6.71 seconds
# Epoch 14/25
# ResNet18 MoE - Loss: 3.1675, Acc: 0.3026 | Val Loss: 250745083332.8479, Val Acc: 0.3004
# ResNet18 MoE Training Duration: 84.55 seconds
# ResNet18 MoE Validation Duration: 6.60 seconds
# Epoch 15/25
# ResNet18 MoE - Loss: 3.0454, Acc: 0.3218 | Val Loss: 3.3060, Val Acc: 0.3252
# ResNet18 MoE Training Duration: 84.98 seconds
# ResNet18 MoE Validation Duration: 6.43 seconds
# Epoch 16/25
# ResNet18 MoE - Loss: 2.9405, Acc: 0.3424 | Val Loss: 3.0263, Val Acc: 0.3387
# ResNet18 MoE Training Duration: 84.44 seconds
# ResNet18 MoE Validation Duration: 6.47 seconds
# Epoch 17/25
# ResNet18 MoE - Loss: 2.8489, Acc: 0.3581 | Val Loss: 2.9833, Val Acc: 0.3490
# ResNet18 MoE Training Duration: 84.55 seconds
# ResNet18 MoE Validation Duration: 6.50 seconds
# Epoch 18/25
# ResNet18 MoE - Loss: 2.8417, Acc: 0.3611 | Val Loss: 3.2071, Val Acc: 0.3572
# ResNet18 MoE Training Duration: 84.64 seconds
# ResNet18 MoE Validation Duration: 6.43 seconds
# Epoch 19/25
# ResNet18 MoE - Loss: 2.7174, Acc: 0.3801 | Val Loss: 2.9148, Val Acc: 0.3662
# ResNet18 MoE Training Duration: 84.78 seconds
# ResNet18 MoE Validation Duration: 6.42 seconds
# Epoch 20/25
# ResNet18 MoE - Loss: 2.6757, Acc: 0.3882 | Val Loss: 2.8588, Val Acc: 0.3776
# ResNet18 MoE Training Duration: 84.33 seconds
# ResNet18 MoE Validation Duration: 6.36 seconds
# Epoch 21/25
# ResNet18 MoE - Loss: 2.1842, Acc: 0.4204 | Val Loss: 2.3218, Val Acc: 0.4007
# ResNet18 MoE Training Duration: 84.34 seconds
# ResNet18 MoE Validation Duration: 6.69 seconds
# Epoch 22/25
# ResNet18 MoE - Loss: 2.1172, Acc: 0.4359 | Val Loss: 2.4007, Val Acc: 0.4164
# ResNet18 MoE Training Duration: 85.08 seconds
# ResNet18 MoE Validation Duration: 6.39 seconds
# Epoch 23/25
# ResNet18 MoE - Loss: 2.0863, Acc: 0.4408 | Val Loss: 2.3067, Val Acc: 0.4240
# ResNet18 MoE Training Duration: 84.11 seconds
# ResNet18 MoE Validation Duration: 6.47 seconds
# Epoch 24/25
# ResNet18 MoE - Loss: 2.0348, Acc: 0.4559 | Val Loss: 2.2262, Val Acc: 0.4239
# ResNet18 MoE Training Duration: 84.65 seconds
# ResNet18 MoE Validation Duration: 6.48 seconds
# Epoch 25/25
# ResNet18 MoE - Loss: 1.9920, Acc: 0.4631 | Val Loss: 2.2241, Val Acc: 0.4315
# ResNet18 MoE Training Duration: 84.82 seconds
# ResNet18 MoE Validation Duration: 6.54 seconds
