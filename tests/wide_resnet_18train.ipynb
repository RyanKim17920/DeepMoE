# %%
import time
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import StepLR
from deepmoe_utils import deepmoe_loss
from deepResNet import resnet18_moe
from ResNet import resnet18

# %%
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761))
])

train_dataset = datasets.CIFAR100(root='./data', train=True, download=True, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=4)

val_dataset = datasets.CIFAR100(root='./data', train=False, download=True, transform=transform)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False, num_workers=4)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169001437/169001437 [02:39<00:00, 1059209.52it/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified

# %%
def train(model, device, train_loader, optimizer, criterion, moe=False):
    model.train()
    total_loss, correct = 0, 0
    for data, target in train_loader:
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        if not moe:
            output = model(data)
            loss = criterion(output, target)
        else:
            output, gates, emb_y_hat = model(data)
            loss = criterion(output, emb_y_hat, target, gates)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        pred = output.argmax(dim=1, keepdim=True)
        correct += pred.eq(target.view_as(pred)).sum().item()
    
    return total_loss / len(train_loader), correct / len(train_loader.dataset)

# %%
def validate(model, device, val_loader, criterion, moe=False):
    model.eval()
    total_loss, correct = 0, 0
    with torch.no_grad():
        for data, target in val_loader:
            data, target = data.to(device), target.to(device)
            if not moe:
                output = model(data)
                loss = criterion(output, target)
            else:
                output, gates, emb_y_hat = model(data)
                loss = criterion(output, emb_y_hat, target, gates)
            
            total_loss += loss.item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
            
    return total_loss / len(val_loader), correct / len(val_loader.dataset)

# %%
def main():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    # Initialize models
    model_resnet18_moe = resnet18_moe(num_classes=100, wide=True).to(device)
    
    # Initialize optimizers
    optimizer_resnet18_moe = optim.Adam(model_resnet18_moe.parameters(), lr=0.001)
    
    # Initialize criteria and schedulers
    moe_criterion = deepmoe_loss(lambda_val=0.001, mu=1.0)
    scheduler_resnet18_moe = StepLR(optimizer_resnet18_moe, step_size=20, gamma=0.5)
    
    num_epochs = 50
    for epoch in range(num_epochs):
        print(f"Epoch {epoch+1}/{num_epochs}")
        
        # Update moe_criterion parameters for the last 5 epochs
        if epoch >= num_epochs - 5:
            moe_criterion = deepmoe_loss(lambda_val=0.0, mu=0.0)
        
        # Train ResNet-18 MoE
        start_time_train_resnet18_moe = time.time()
        train_loss_resnet18_moe, train_acc_resnet18_moe = train(model_resnet18_moe, device, train_loader, optimizer_resnet18_moe, moe_criterion, True)
        end_time_train_resnet18_moe = time.time()
        train_duration_resnet18_moe = end_time_train_resnet18_moe - start_time_train_resnet18_moe
        
        # Validate ResNet-18 MoE
        start_time_val_resnet18_moe = time.time()
        val_loss_resnet18_moe, val_acc_resnet18_moe = validate(model_resnet18_moe, device, val_loader, moe_criterion, True)
        end_time_val_resnet18_moe = time.time()
        val_duration_resnet18_moe = end_time_val_resnet18_moe - start_time_val_resnet18_moe
        
        print(f"ResNet18 MoE - Loss: {train_loss_resnet18_moe:.4f}, Acc: {train_acc_resnet18_moe:.4f} | Val Loss: {val_loss_resnet18_moe:.4f}, Val Acc: {val_acc_resnet18_moe:.4f}")
        print(f"ResNet18 MoE Training Duration: {train_duration_resnet18_moe:.2f} seconds")
        print(f"ResNet18 MoE Validation Duration: {val_duration_resnet18_moe:.2f} seconds")
        
        # Update schedulers
        scheduler_resnet18_moe.step()

if __name__ == "__main__":
    main()
# Out:
# Epoch 1/50
# ResNet18 MoE - Loss: 8.4895, Acc: 0.0721 | Val Loss: 8.7148, Val Acc: 0.0988
# ResNet18 MoE Training Duration: 183.44 seconds
# ResNet18 MoE Validation Duration: 12.24 seconds
# Epoch 2/50
# ResNet18 MoE - Loss: 7.7881, Acc: 0.1194 | Val Loss: 2100489.2020, Val Acc: 0.1286
# ResNet18 MoE Training Duration: 182.97 seconds
# ResNet18 MoE Validation Duration: 12.29 seconds
# Epoch 3/50
# ResNet18 MoE - Loss: 7.3869, Acc: 0.1609 | Val Loss: 4601.8628, Val Acc: 0.1634
# ResNet18 MoE Training Duration: 181.58 seconds
# ResNet18 MoE Validation Duration: 12.18 seconds
# Epoch 4/50
# ResNet18 MoE - Loss: 6.9343, Acc: 0.2015 | Val Loss: 11763919277.3472, Val Acc: 0.2084
# ResNet18 MoE Training Duration: 180.48 seconds
# ResNet18 MoE Validation Duration: 12.24 seconds
# Epoch 5/50
# ResNet18 MoE - Loss: 6.4722, Acc: 0.2386 | Val Loss: 1487.4166, Val Acc: 0.2428
# ResNet18 MoE Training Duration: 180.34 seconds
# ResNet18 MoE Validation Duration: 12.31 seconds
# Epoch 6/50
# ResNet18 MoE - Loss: 6.0446, Acc: 0.2760 | Val Loss: 114.0862, Val Acc: 0.2741
# ResNet18 MoE Training Duration: 180.18 seconds
# ResNet18 MoE Validation Duration: 12.26 seconds
# Epoch 7/50
# ResNet18 MoE - Loss: 5.6674, Acc: 0.3141 | Val Loss: 6249702723826.1309, Val Acc: 0.3192
# ResNet18 MoE Training Duration: 179.92 seconds
# ResNet18 MoE Validation Duration: 12.21 seconds
# Epoch 8/50
# ResNet18 MoE - Loss: 5.3860, Acc: 0.3413 | Val Loss: 58.2837, Val Acc: 0.3370
# ResNet18 MoE Training Duration: 179.97 seconds
# ResNet18 MoE Validation Duration: 12.21 seconds
# Epoch 9/50
# ResNet18 MoE - Loss: 5.2077, Acc: 0.3623 | Val Loss: 253976177246601.0000, Val Acc: 0.3563
# ResNet18 MoE Training Duration: 180.00 seconds
# ResNet18 MoE Validation Duration: 12.18 seconds
# Epoch 10/50
# ResNet18 MoE - Loss: 4.8305, Acc: 0.3965 | Val Loss: 482963.9738, Val Acc: 0.3726
# ResNet18 MoE Training Duration: 180.05 seconds
# ResNet18 MoE Validation Duration: 12.17 seconds
# Epoch 11/50
# ResNet18 MoE - Loss: 4.6819, Acc: 0.4151 | Val Loss: 8.9003, Val Acc: 0.3946
# ResNet18 MoE Training Duration: 179.99 seconds
# ResNet18 MoE Validation Duration: 12.20 seconds
# Epoch 12/50
# ResNet18 MoE - Loss: 4.6651, Acc: 0.4156 | Val Loss: 65345022.6536, Val Acc: 0.3922
# ResNet18 MoE Training Duration: 179.86 seconds
# ResNet18 MoE Validation Duration: 12.33 seconds
# Epoch 13/50
# ResNet18 MoE - Loss: 4.3608, Acc: 0.4512 | Val Loss: 4797498.9117, Val Acc: 0.4283
# ResNet18 MoE Training Duration: 179.93 seconds
# ResNet18 MoE Validation Duration: 12.22 seconds
# Epoch 14/50
# ResNet18 MoE - Loss: 4.0972, Acc: 0.4790 | Val Loss: 385.9415, Val Acc: 0.4477
# ResNet18 MoE Training Duration: 179.89 seconds
# ResNet18 MoE Validation Duration: 12.20 seconds
# Epoch 15/50
# ResNet18 MoE - Loss: 4.0243, Acc: 0.4882 | Val Loss: 632430795928798848.0000, Val Acc: 0.3974
# ResNet18 MoE Training Duration: 179.76 seconds
# ResNet18 MoE Validation Duration: 12.19 seconds
# Epoch 16/50
# ResNet18 MoE - Loss: 3.9514, Acc: 0.4958 | Val Loss: 92537.8276, Val Acc: 0.4624
# ResNet18 MoE Training Duration: 179.87 seconds
# ResNet18 MoE Validation Duration: 12.24 seconds
# Epoch 17/50
# ResNet18 MoE - Loss: 3.7391, Acc: 0.5214 | Val Loss: 51188069578.6920, Val Acc: 0.4688
# ResNet18 MoE Training Duration: 179.91 seconds
# ResNet18 MoE Validation Duration: 12.17 seconds
# Epoch 18/50
# ResNet18 MoE - Loss: 3.5977, Acc: 0.5384 | Val Loss: 5721023441018498.0000, Val Acc: 0.4775
# ResNet18 MoE Training Duration: 179.68 seconds
# ResNet18 MoE Validation Duration: 12.22 seconds
# Epoch 19/50
# ResNet18 MoE - Loss: 3.6136, Acc: 0.5407 | Val Loss: 6.4941, Val Acc: 0.4673
# ResNet18 MoE Training Duration: 179.78 seconds
# ResNet18 MoE Validation Duration: 12.26 seconds
# Epoch 20/50
# ResNet18 MoE - Loss: 3.5197, Acc: 0.5523 | Val Loss: 72.2040, Val Acc: 0.4868
# ResNet18 MoE Training Duration: 179.72 seconds
# ResNet18 MoE Validation Duration: 12.20 seconds
# Epoch 21/50
# ResNet18 MoE - Loss: 3.0879, Acc: 0.6055 | Val Loss: 7644443.7695, Val Acc: 0.5193
# ResNet18 MoE Training Duration: 179.80 seconds
# ResNet18 MoE Validation Duration: 12.19 seconds
# Epoch 22/50
# ResNet18 MoE - Loss: 2.9798, Acc: 0.6208 | Val Loss: 222175.0290, Val Acc: 0.5247
# ResNet18 MoE Training Duration: 179.67 seconds
# ResNet18 MoE Validation Duration: 12.19 seconds
# Epoch 23/50
# ResNet18 MoE - Loss: 3.0205, Acc: 0.6201 | Val Loss: 248.0561, Val Acc: 0.5226
# ResNet18 MoE Training Duration: 179.51 seconds
# ResNet18 MoE Validation Duration: 12.18 seconds
# Epoch 24/50
# ResNet18 MoE - Loss: 2.9170, Acc: 0.6341 | Val Loss: 306.2586, Val Acc: 0.5242
# ResNet18 MoE Training Duration: 179.32 seconds
# ResNet18 MoE Validation Duration: 12.17 seconds
# Epoch 25/50
# ResNet18 MoE - Loss: 2.9037, Acc: 0.6363 | Val Loss: 81958.5598, Val Acc: 0.5290
# ResNet18 MoE Training Duration: 179.55 seconds
# ResNet18 MoE Validation Duration: 12.17 seconds
# Epoch 26/50
# ResNet18 MoE - Loss: 2.7767, Acc: 0.6494 | Val Loss: nan, Val Acc: 0.5353
# ResNet18 MoE Training Duration: 179.53 seconds
# ResNet18 MoE Validation Duration: 12.18 seconds
# Epoch 27/50
# ResNet18 MoE - Loss: 2.7005, Acc: 0.6605 | Val Loss: 105.7105, Val Acc: 0.5321
# ResNet18 MoE Training Duration: 179.45 seconds
# ResNet18 MoE Validation Duration: 12.17 seconds
# Epoch 28/50
# ResNet18 MoE - Loss: 2.6537, Acc: 0.6670 | Val Loss: 978.1963, Val Acc: 0.5445
# ResNet18 MoE Training Duration: 179.45 seconds
# ResNet18 MoE Validation Duration: 12.21 seconds
# Epoch 29/50
# ResNet18 MoE - Loss: 2.6347, Acc: 0.6692 | Val Loss: 50.8353, Val Acc: 0.5372
# ResNet18 MoE Training Duration: 179.39 seconds
# ResNet18 MoE Validation Duration: 12.20 seconds
# Epoch 30/50
# ResNet18 MoE - Loss: 2.5410, Acc: 0.6835 | Val Loss: 109.7829, Val Acc: 0.5401
# ResNet18 MoE Training Duration: 179.62 seconds
# ResNet18 MoE Validation Duration: 12.16 seconds
# Epoch 31/50
# ResNet18 MoE - Loss: 2.4886, Acc: 0.6900 | Val Loss: 5.9940, Val Acc: 0.5373
# ResNet18 MoE Training Duration: 179.39 seconds
# ResNet18 MoE Validation Duration: 12.18 seconds
# Epoch 32/50
# ResNet18 MoE - Loss: 2.4997, Acc: 0.6888 | Val Loss: 9.7103, Val Acc: 0.5425
# ResNet18 MoE Training Duration: 179.36 seconds
# ResNet18 MoE Validation Duration: 12.27 seconds
# Epoch 33/50
# ResNet18 MoE - Loss: 2.4783, Acc: 0.6896 | Val Loss: 253.7602, Val Acc: 0.5467
# ResNet18 MoE Training Duration: 179.50 seconds
# ResNet18 MoE Validation Duration: 12.20 seconds
# Epoch 34/50
# ResNet18 MoE - Loss: 2.3741, Acc: 0.7091 | Val Loss: 4.1711, Val Acc: 0.5522
# ResNet18 MoE Training Duration: 179.54 seconds
# ResNet18 MoE Validation Duration: 12.18 seconds
# Epoch 35/50
# ResNet18 MoE - Loss: 2.3258, Acc: 0.7110 | Val Loss: 5.4174, Val Acc: 0.5431
# ResNet18 MoE Training Duration: 179.63 seconds
# ResNet18 MoE Validation Duration: 12.53 seconds
# Epoch 36/50
# ResNet18 MoE - Loss: 2.2940, Acc: 0.7168 | Val Loss: 44306.8596, Val Acc: 0.5525
# ResNet18 MoE Training Duration: 180.21 seconds
# ResNet18 MoE Validation Duration: 12.41 seconds
# Epoch 37/50
# ResNet18 MoE - Loss: 2.2473, Acc: 0.7250 | Val Loss: 515659.9761, Val Acc: 0.5458
# ResNet18 MoE Training Duration: 179.54 seconds
# ResNet18 MoE Validation Duration: 12.16 seconds
# Epoch 38/50
# ResNet18 MoE - Loss: 2.2222, Acc: 0.7302 | Val Loss: 19238870.5361, Val Acc: 0.5500
# ResNet18 MoE Training Duration: 179.38 seconds
# ResNet18 MoE Validation Duration: 12.23 seconds
# Epoch 39/50
# ResNet18 MoE - Loss: 2.1856, Acc: 0.7332 | Val Loss: 7.1526, Val Acc: 0.5504
# ResNet18 MoE Training Duration: 179.42 seconds
# ResNet18 MoE Validation Duration: 12.33 seconds
# Epoch 40/50
# ResNet18 MoE - Loss: 2.1536, Acc: 0.7382 | Val Loss: 102118.0297, Val Acc: 0.5559
# ResNet18 MoE Training Duration: 179.58 seconds
# ResNet18 MoE Validation Duration: 12.22 seconds
# Epoch 41/50
# ResNet18 MoE - Loss: 1.9716, Acc: 0.7697 | Val Loss: 97.9164, Val Acc: 0.5586
# ResNet18 MoE Training Duration: 179.44 seconds
# ResNet18 MoE Validation Duration: 12.15 seconds
# Epoch 42/50
# ResNet18 MoE - Loss: 1.9362, Acc: 0.7744 | Val Loss: 26.0245, Val Acc: 0.5566
# ResNet18 MoE Training Duration: 179.54 seconds
# ResNet18 MoE Validation Duration: 12.23 seconds
# Epoch 43/50
# ResNet18 MoE - Loss: 1.9096, Acc: 0.7807 | Val Loss: 4.8810, Val Acc: 0.5634
# ResNet18 MoE Training Duration: 179.39 seconds
# ResNet18 MoE Validation Duration: 12.12 seconds
# Epoch 44/50
# ResNet18 MoE - Loss: 1.8709, Acc: 0.7863 | Val Loss: 1041008.8443, Val Acc: 0.5662
# ResNet18 MoE Training Duration: 179.44 seconds
# ResNet18 MoE Validation Duration: 12.21 seconds
# Epoch 45/50
# ResNet18 MoE - Loss: 1.8449, Acc: 0.7914 | Val Loss: 5.1476, Val Acc: 0.5627
# ResNet18 MoE Training Duration: 179.31 seconds
# ResNet18 MoE Validation Duration: 12.17 seconds
# Epoch 46/50
# ResNet18 MoE - Loss: 0.6775, Acc: 0.7952 | Val Loss: 6463968.0114, Val Acc: 0.5663
# ResNet18 MoE Training Duration: 179.31 seconds
# ResNet18 MoE Validation Duration: 12.33 seconds
# Epoch 47/50
# ResNet18 MoE - Loss: 0.6647, Acc: 0.7989 | Val Loss: 2.7599, Val Acc: 0.5698
# ResNet18 MoE Training Duration: 179.91 seconds
# ResNet18 MoE Validation Duration: 12.52 seconds
# Epoch 48/50
# ResNet18 MoE - Loss: 0.6543, Acc: 0.8002 | Val Loss: 117.3980, Val Acc: 0.5707
# ResNet18 MoE Training Duration: 180.24 seconds
# ResNet18 MoE Validation Duration: 12.20 seconds
# Epoch 49/50
# ResNet18 MoE - Loss: 0.6390, Acc: 0.8071 | Val Loss: 927.8069, Val Acc: 0.5667
# ResNet18 MoE Training Duration: 179.64 seconds
# ResNet18 MoE Validation Duration: 12.19 seconds
# Epoch 50/50
